# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# #### 필요 Library 불러오기

# %%
import numpy as np
import pandas as pd
import random
import math
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.데이터 호출 및 형태 확인

# %%
org_dt = pd.read_csv(r"C:\Users\seolbluewings\Desktop\sample\creditcard.csv")

# %%
org_dt.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# - Time 변수는 의미파악이 어려워 제외시키기로 결정
# - V1~V28 변수는 고객의 개인정보 유출 우려로 인해 raw data 컬럼이 아닌, PCA 결과로 생성된 변수로 여겨짐
# - Amount는 거래 금액을 의미
# - Class : 1값이 사기성 거래, 0값이 정상 거래

# %%
dt = org_dt.iloc[:,1:]

# %%
dt.head(5)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 30 columns):
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# V24       284807 non-null float64
# ...

# %% [markdown]
# - .info() 함수를 통해 데이터에 대한 전반적 정보를 확인하였는데 null값이 없는 아주 깔끔한 데이터이다. null값 처리에 대한 과정은 생략!

# %%
dt.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15 -1.552563e-15
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01
# max    2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01  3.480167e+01
#
#                  V6            V7            V8            V9           V10  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15  1.768627e-15
# ...

# %%
counts = dt.Class.value_counts()

plt.figure(figsize=(7,5))
sns.barplot(x=counts.index, y=counts)
plt.title('Count of Fraudulent vs. Non-Fraudulent Transactions')
plt.ylabel('Count')
plt.xlabel('Class (0:Non-Fraudulent, 1:Fraudulent)')
# Out:
# Text(0.5, 0, 'Class (0:Non-Fraudulent, 1:Fraudulent)')

# %% [markdown]
# - 정상거래가 압도적으로 많으며 사기성 거래는 극히 소수인 것으로 보인다. 따라서 모델 형성 시, 단순한 분류 정확성으로 기준점을 삼는 것은 적절하지 않을 수 있다.
# - V1~V28 변수들도 적당한 수준으로 Scaling 된 것으로 보이며
# - Amount값은 극단적인 값이 평균에 상당한 영향을 미치는 것으로 보인다

# %% [markdown]
# ### 2.EDA

# %% [markdown]
# #### 가정 1. 사기성 거래와 정상 거래를 구분할 수 있는 변수가 존재할 것이다
# - 예를 들면 거래 금액이 비정상적으로 큰 경우, 이를 사기성 거래로 여길 가능성이 높다고 보는게 타당
# - 그 외에도 V1~V28 중에서 사기성 거래와 정상 거래를 확실하게 구분할 수 있는 변수가 있을 것이라고 가정

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x= 'Class', y = 'Amount', data =dt, hue = 'Class', palette = 'Set1')

# %%
fig, (ax1,ax2) = plt.subplots(2,1, figsize = (10,5), sharex = True)
ax1.hist(dt.Amount[dt.Class==0],bins=50,color='g',alpha=0.5)
ax1.set_yscale('log') # to see the tails
ax1.set_title('Genuine') # to see the tails
ax1.set_ylabel('# transactions')
ax2.hist(dt.Amount[dt.Class==1],bins=50,color='r',alpha=0.5)
ax2.set_yscale('log') # to see the tails
ax2.set_title('Fraud') # to see the tails
ax2.set_xlabel('Amount ($)')
ax2.set_ylabel('# transactions')
# Out:
# Text(0, 0.5, '# transactions')

# %% [markdown]
# - Amount 변수부터 살펴보았는데 이 그림만으로 금액이 높다고 사기성 거래라고 단언할 수 없다고 말할 수 있을 것 같다. 그래도 여전히 Amount는 중요한 변수일 것으로 생각된다.

# %% [markdown]
# #### V1~V28 변수가 각 Class별로 어떻게 분포되어 있는가를 살펴본다
# - V3,V4,V10,V11,V12,V14,V16,V17,V18,V19 정도의 변수가 Class별로 분포의 차이를 보임

# %%
fig, ax = plt.subplots(7,1, figsize = (10,10))

for iter in range(1,8):
    plt.subplot(7,1,iter)
    sns.kdeplot(dt[dt['Class']==0]['V'+str(iter)], label="Class 0", shade=True)
    sns.kdeplot(dt[dt['Class']==1]['V'+str(iter)], label="Class 1", shade=True)
    plt.title('V'+str(iter))

# %%
fig, ax = plt.subplots(7,1, figsize = (10,10))

for iter in range(8,15):
    plt.subplot(7,1,iter-7)
    sns.kdeplot(dt[dt['Class']==0]['V'+str(iter)], label="Class 0", shade=True)
    sns.kdeplot(dt[dt['Class']==1]['V'+str(iter)], label="Class 1", shade=True)
    plt.title('V'+str(iter))

# %%
fig, ax = plt.subplots(7,1, figsize = (10,10))

for iter in range(15,22):
    plt.subplot(7,1,iter-14)
    sns.kdeplot(dt[dt['Class']==0]['V'+str(iter)], label="Class 0", shade=True)
    sns.kdeplot(dt[dt['Class']==1]['V'+str(iter)], label="Class 1", shade=True)
    plt.title('V'+str(iter))

# %%
fig, ax = plt.subplots(7,1, figsize = (10,10))

for iter in range(22,29):
    plt.subplot(7,1,iter-21)
    sns.kdeplot(dt[dt['Class']==0]['V'+str(iter)], label="Class 0", shade=True)
    sns.kdeplot(dt[dt['Class']==1]['V'+str(iter)], label="Class 1", shade=True)
    plt.title('V'+str(iter))

# %% [markdown]
# - 변수들 간의 Joint 분포를 살펴보는 것도 좋아보이지만, Naive Bayes Classifier에 한정짓는다면 그렇게 하지 않아도 될 것이다
# - 왜냐면, Naive Bayes Classifier는 각 변수들간의 독립성을 가정하기 때문이다

# %% [markdown]
# - 이렇게 각 Class 결과별 분포를 Naive Bayes Classifier에서는 더욱 의미가 있는 작업으로 간주될 수 있다.
# - 왜냐면, Naive Bayes Classifier는 $p(x\vert C)$ 값을 고려하기 때문이다.
# - 따라서, 각 Class별로 분포 결과가 다른 것은 사기성 거래를 분류하는데 큰 도움을 줄 것으로 생각된다.'
# - 변수가 너무 많기도 하고 지금은 그냥 간략한 예시를 보여주기 위함이기 때문에 앞서 언급했던 유의미한 차이가 있다고 판단되는 일부 변수들 (V3,V4,V10,V11,V12,V14,V16,V17,V18,V19) 들만 활용하기로 하자. 거래금액을 고려하는 것이 합리적이지만, 그냥 Naive Bayes Classifier의 과정을 맛보기 위한 것이므로 빼도록 하자

# %%
f_dt = dt[['V3','V4','V10','V11','V12','V14','V16','V17','V18','V19','Class']]

# %%
f_dt.head(5)
# Out:
#          V3        V4       V10       V11       V12       V14       V16  \
# 0  2.536347  1.378155  0.090794 -0.551600 -0.617801 -0.311169 -0.470401
# 1  0.166480  0.448154 -0.166974  1.612727  1.065235 -0.143772  0.463917
# 2  1.773209  0.379780  0.207643  0.624501  0.066084 -0.165946 -2.890083
# 3  1.792993 -0.863291 -0.054952 -0.226487  0.178228 -0.287924 -1.059647
# 4  1.548718  0.403034  0.753074 -0.822843  0.538196 -1.119670 -0.451449
#
#         V17       V18       V19  Class
# 0  0.207971  0.025791  0.403993      0
# 1 -0.114805 -0.183361 -0.145783      0
# 2  1.109969 -0.121359 -2.261857      0
# 3 -0.684093  1.965775 -1.232622      0
# 4 -0.237033 -0.038195  0.803487      0

# %% [markdown]
# #### Naive Bayes  Classifier 모델 만들기
# - 데이터셋을 train set과 test set으로 구분할 필요가 있겠다
# - train set을 통해 최적의 모델을 만들어내고 test set에서의 결과를 확인해보자
# - 다만 지금 주어진 데이터와 같이 unbalanced data일 경우, train set과 test set을 나눌 때 주의할 필요가 있다

# %%
from sklearn.model_selection import train_test_split

# %%
X = f_dt.iloc[:,:-1]
y = f_dt.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %% [markdown]
# #### SMOTE 를 이용하여 train data set의 unbalanced data가 balance를 갖출 수 있도록 처리하기

# %%
from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
X_resampled, y_resampled = SMOTE(random_state=0).fit_resample(X_train, y_train)

# %% [markdown]
# #### Naive Bayes Classifier를 계산하기 위한 라이브러리 불러오기
# - 이 문제에서는 각 X변수가 연속형 변수임에 주목할 필요가 있다.
# - 우리는 각 변수가 가우시안 분포를 따를 것으로 가정하여 Gaussian Naive Bayes Classifier를 활용하기로 한다
# - 아래 코드에서 GaussianNB() 함수를 활용하는 부분이 바로 Naive Bayes Classifier 계산이 이루어지는 곳이다

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix,auc,roc_auc_score
from sklearn.metrics import recall_score, precision_score, accuracy_score, f1_score

# %%
def get_predictions(clf, X_train, y_train, X_test):
    ### Classifier 생성
    clf = clf
    ### train data set을 이용한 모델 학습
    clf.fit(X_train,y_train)
    ### test data set을 이용한 예측 결과 출력
    y_pred = clf.predict(X_test)
    # test data set을 이용한 예측 확률을 출력
    y_pred_prob = clf.predict_proba(X_test)
    return y_pred, y_pred_prob

# %% [markdown]
# - 예측의 정확성에 대한 평가지표는 단순히 정확성만 따져서는 안된다.
# - 이 모델은 사기성 거래를 탐지하는 것을 목표로 하므로, 실제 사기성 거래를 사기성 거래로 예측한게 얼마나 되는가를 살펴볼 수 있는 Recall 지표가 중요할 것으로 생각된다.

# %%
def print_scores(y_test,y_pred,y_pred_prob):
    print("recall score: ", recall_score(y_test,y_pred))
    print("precision score: ", precision_score(y_test,y_pred))
    print("f1 score: ", f1_score(y_test,y_pred))
    print("accuracy score: ", accuracy_score(y_test,y_pred))
    print("ROC AUC: {}".format(roc_auc_score(y_test, y_pred_prob[:,1])))

# %%
y_pred, y_pred_prob = get_predictions(GaussianNB(), X_train, y_train, X_test)
print_scores(y_test,y_pred,y_pred_prob)
# Out:
# recall score:  0.8367346938775511
# precision score:  0.16644113667117727
# f1 score:  0.27765237020316025
# accuracy score:  0.9925096263005746
# ROC AUC: 0.9679424480353012

# %%
y_pred, y_pred_prob = get_predictions(GaussianNB(), X_resampled, y_resampled, X_test)
print_scores(y_test,y_pred,y_pred_prob)
# Out:
# recall score:  0.8435374149659864
# precision score:  0.09531129900076864
# f1 score:  0.1712707182320442
# accuracy score:  0.9859555493135774
# ROC AUC: 0.9679962422973315

# %% [markdown]
# - SMOTE 를 통해 처리한 결과에서 더 향상된 recall score가 나왔다.
# - 포스팅에서 소개했던 것처럼 Naive Bayes Classifier는 가장 간단한 형태의 분류 알고리즘이다.
# - 더욱 향상된 모델을 사용하면 더 높은 recall score를 출력해낼 수도 있다.
