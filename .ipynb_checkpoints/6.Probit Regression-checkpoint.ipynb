# %%
import numpy as np
import pandas as pd
import random
import math
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm
from scipy.stats import truncnorm
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 5)

# %% [markdown]
# #### 1. Generate Data

# %%
random.seed(50120057)

# %% [markdown]
# #### 1-1. Create data X between (-2,2)
# #### 1-2. Create N*D size matrix

# %%
N = 4000
D = 2
x =  np.linspace(start = -2, stop = 2, num = 4000)
X = np.transpose(np.array([np.repeat(1,N),x]))

# %% [markdown]
# #### 1-3. Set true value of $\beta$

# %%
tr_beta = [-1,2.5]

# %% [markdown]
# #### 1-4. By using probit function, obtain the vector of probability of success p

# %%
p_mat = norm.cdf(np.dot(X,tr_beta))

# %% [markdown]
# #### 1-5. Generate binary observation data y based on p

# %%
y = np.random.binomial(1, p_mat, N)

# %%
N1 = sum(np.random.binomial(1,p_mat,N))
N0 = N - sum(np.random.binomial(1,p_mat,N))

# %% [markdown]
# #### 2. Gibbs Sampler Step

# %% [markdown]
# #### 2-1. Set prior of beta

# %%
beta_0 = np.repeat(1,D)
sig_0 = np.identity(D)

# %% [markdown]
# #### 2-2. Set initial value

# %%
T = 50000
u = np.repeat(0,N)
beta_mat = np.ones((T,D))

# %%
for iter in range(1,T):
    
    #### 1. sampling step of latent variable U
    
    mu_u = np.dot(X,beta_mat[iter-1,])
    
    lower = -np.inf; upper = 0
    mu =  mu_u[np.where(y==0)]
    sigma = 1
    
    u[np.where(y==0)] = stats.truncnorm.rvs((lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
    
    lower = 0; upper = np.inf
    mu =  mu_u[np.where(y==1)]
    sigma = 1
    
    u[np.where(y==1)] = stats.truncnorm.rvs((lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
    
    ##u[np.where(y==0)] = stats.truncnorm.rvs(loc = mu_u[np.where(y==0)], scale = 1, a= -np.inf, b = 0)
    ##u[np.where(y==1)] = stats.truncnorm.rvs(loc = mu_u[np.where(y==1)], scale = 1, a= 0, b = np.inf)
    
    #### 2. sampling step of parameter beta
  
    sig_pi = np.linalg.inv(np.dot(X.transpose(),X) + np.linalg.inv(sig_0))
    inner_prod = np.dot(X.transpose(),u) + np.dot(np.linalg.inv(sig_0),beta_0)
    mu_pi = np.dot(sig_pi,inner_prod)

    beta_mat[iter,:] = np.random.multivariate_normal(mu_pi, sig_pi)

# %%
Z = stats.truncnorm.rvs((lower - mu) / sigma, (upper - mu) / sigma, loc=mu, scale=sigma)
N = stats.norm(loc=mu, scale=sigma)
data = X.rvs(10000)

# %% [markdown]
# #### 3. Checking Trace plot

# %%
plt.plot(beta_mat[:,0])
plt.xlabel("iteration")
plt.ylabel(r'$\beta_{0}$')
plt.show()

# %%
plt.plot(beta_mat[:,1])
plt.xlabel("iteration")
plt.ylabel(r'$\beta_{1}$')
plt.show()

# %%
sig_pi = np.linalg.inv(np.dot(X.transpose(),X) + np.linalg.inv(sig_0)) 
mu_pi  = np.dot(sig_pi,(np.dot(X.transpose(),u)+ np.dot(sig_0,beta_0)))

# %%
stats.truncnorm.rvs(loc = 33, scale = 1, a = -np.infty, b = -23)
# Out:
# 9.969131486186892

# %%
u[:,list(np.where(y==0))]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-749a35a8a52e> in <module>
# ----> 1 u[:,list(np.where(y==0))]
#
# IndexError: too many indices for array

# %%
type(np.where(y==0))
# Out:
# tuple

# %%
type(u)
# Out:
# numpy.ndarray
