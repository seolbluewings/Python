# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\seolbluewings\Desktop\sample\FullShotsData.csv")

# %%
df.head(5)
# Out:
#          id  minute       result      X      Y        xG         player h_a  \
# 0  378451.0      20  BlockedShot  0.876  0.602  0.019479  Ollie Watkins   h
# 1  378458.0      54  MissedShots  0.878  0.430  0.031428  Ollie Watkins   h
# 2  378464.0      77  MissedShots  0.858  0.679  0.060696  Ollie Watkins   h
# 3  379954.0      34  MissedShots  0.831  0.655  0.127710  Ollie Watkins   a
# 4  379956.0      46  MissedShots  0.943  0.500  0.445354  Ollie Watkins   a
#
#    player_id   situation  year   shotType  match_id       h_team  \
# 0       8865    OpenPlay  2020       Head     14104  Aston Villa
# 1       8865    OpenPlay  2020       Head     14104  Aston Villa
# 2       8865    OpenPlay  2020  RightFoot     14104  Aston Villa
# 3       8865    OpenPlay  2020  RightFoot     14114       Fulham
# 4       8865  FromCorner  2020       Head     14114       Fulham
#
#              a_team  h_goals  a_goals                 date  player_assisted  \
# ...

# %% [markdown]
# #### 선수들의 슈팅 기대득점 데이터
# - 1. 경기 몇분에 슈팅을 시도했는가
# - 2. 슈팅의 결과
# - 3. X,Y 좌표
# - 4. 해당 슈팅의 xG값
# - 5. 슈팅을 시도한 선수와 그 선수가 홈팀 선수인지
# - 6. 슛타입

# %% [markdown]
# #### Plot을 그리는 연습을 위해 일부 선수만 2019~2020년 데이터만 추출해서 그리는 것으로 가정하자
# - Bruno Fernandes / player_id = 1228
# - Son Heung-min / player_id = 453
# - Harry Kane / player_id = 647
# - Roberto Lewandowski / player_id = 227

# %%
dt = df[(df['player_id'].isin(['1228','453','647','227'])) &  (df['year'].isin(['2019','2020'])) ]

# %%
dt.head(5)
# Out:
#              id  minute       result      X      Y        xG         player  \
# 15181  313115.0      32    SavedShot  0.923  0.660  0.052351  Son Heung-Min
# 15182  313117.0      39  MissedShots  0.754  0.593  0.019545  Son Heung-Min
# 15183  313120.0      50  BlockedShot  0.766  0.320  0.019341  Son Heung-Min
# 15184  313128.0      76    SavedShot  0.779  0.694  0.021513  Son Heung-Min
# 15185  313132.0      88  BlockedShot  0.897  0.693  0.044125  Son Heung-Min
#
#       h_a  player_id situation  year   shotType  match_id     h_team  \
# 15181   h        453  OpenPlay  2019  RightFoot     11672  Tottenham
# 15182   h        453  OpenPlay  2019  RightFoot     11672  Tottenham
# 15183   h        453  OpenPlay  2019  RightFoot     11672  Tottenham
# 15184   h        453  OpenPlay  2019   LeftFoot     11672  Tottenham
# 15185   h        453  OpenPlay  2019  RightFoot     11672  Tottenham
#
#                  a_team  h_goals  a_goals                 date  \
# ...

# %%
plt.figure(figsize=(15,8))

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x= "player", y= "xG",hue="h_a", data=dt)
